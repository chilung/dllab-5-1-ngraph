# %%
import os
import time
import onnx

# %%
onnx_filename = 'alexnet.onnx'
model_alexnet = onnx.load(onnx_filename)
print(onnx.helper.printable_graph(model_alexnet.graph))
onnx.checker.check_model(model_alexnet)
# Out:
# graph torch-jit-export (
#   %0[FLOAT, 10x3x224x224]
# ) initializers (
#   %1[FLOAT, 64x3x11x11]
#   %2[FLOAT, 64]
#   %3[FLOAT, 192x64x5x5]
#   %4[FLOAT, 192]
#   %5[FLOAT, 384x192x3x3]
#   %6[FLOAT, 384]
#   %7[FLOAT, 256x384x3x3]
#   %8[FLOAT, 256]
#   %9[FLOAT, 256x256x3x3]
#   %10[FLOAT, 256]
#   %11[FLOAT, 4096x9216]
#   %12[FLOAT, 4096]
#   %13[FLOAT, 4096x4096]
#   %14[FLOAT, 4096]
#   %15[FLOAT, 1000x4096]
#   %16[FLOAT, 1000]
# ) {
#   %17 = Conv[dilations = [1, 1], group = 1, kernel_shape = [11, 11], pads = [2, 2, 2, 2], strides = [4, 4]](%0, %1, %2)
#   %18 = Relu(%17)
#   %19 = MaxPool[kernel_shape = [3, 3], pads = [0, 0, 0, 0], strides = [2, 2]](%18)
#   %20 = Conv[dilations = [1, 1], group = 1, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%19, %3, %4)
#   %21 = Relu(%20)
#   %22 = MaxPool[kernel_shape = [3, 3], pads = [0, 0, 0, 0], strides = [2, 2]](%21)
# ...

# %%
onnx_filename = 'resnet18.onnx'
model_resnet18 = onnx.load(onnx_filename)
onnx.checker.check_model(model_resnet18)
print(onnx.helper.printable_graph(model_resnet18.graph))
# Out:
# graph torch-jit-export (
#   %0[FLOAT, 10x3x224x224]
# ) initializers (
#   %1[FLOAT, 64x3x7x7]
#   %2[FLOAT, 64]
#   %3[FLOAT, 64]
#   %4[FLOAT, 64]
#   %5[FLOAT, 64]
#   %6[FLOAT, 64x64x3x3]
#   %7[FLOAT, 64]
#   %8[FLOAT, 64]
#   %9[FLOAT, 64]
#   %10[FLOAT, 64]
#   %11[FLOAT, 64x64x3x3]
#   %12[FLOAT, 64]
#   %13[FLOAT, 64]
#   %14[FLOAT, 64]
#   %15[FLOAT, 64]
#   %16[FLOAT, 64x64x3x3]
#   %17[FLOAT, 64]
#   %18[FLOAT, 64]
#   %19[FLOAT, 64]
#   %20[FLOAT, 64]
#   %21[FLOAT, 64x64x3x3]
#   %22[FLOAT, 64]
#   %23[FLOAT, 64]
#   %24[FLOAT, 64]
#   %25[FLOAT, 64]
#   %26[FLOAT, 128x64x3x3]
#   %27[FLOAT, 128]
#   %28[FLOAT, 128]
#   %29[FLOAT, 128]
#   %30[FLOAT, 128]
#   %31[FLOAT, 128x128x3x3]
#   %32[FLOAT, 128]
#   %33[FLOAT, 128]
#   %34[FLOAT, 128]
#   %35[FLOAT, 128]
#   %36[FLOAT, 128x64x1x1]
#   %37[FLOAT, 128]
#   %38[FLOAT, 128]
#   %39[FLOAT, 128]
#   %40[FLOAT, 128]
#   %41[FLOAT, 128x128x3x3]
#   %42[FLOAT, 128]
#   %43[FLOAT, 128]
#   %44[FLOAT, 128]
# ...
